# %% [markdown]
# # <font color = orange>My ideal holiday</font>

# %% [markdown]
# [Purpose](#What-is-the-purpose-of-this-notebook?)

# %% [markdown]
# [Selfie](#Selfie-Time!)

# %% [markdown]
# [Beach Picture](#Beautiful-Thailand!)

# %% [markdown]
# [Activities](#My-ideal-holiday-activities-in-bullet-points:)

# %% [markdown]
# [Video](#Video)

# %% [markdown]
# ### What is the purpose of this notebook?
#
# 1. Give the notebook a heading title
# 2. Explain the purpose of the notebook with a markdown cell
# 3. Write a function that takes an input - which will be the selected person's name
# 4. upload a photo of that person to the notebook
# 5. Write a function that takes input for their holidays preference. This can be one question or multiple questions to understand this person's preferences. Make sure you test it yourself.
# 6. Add a photo or screenshot of the holiday destination
# 7. Add bullet points of the top 3 things that the person likes to do at this destination.
# 8. Try to make the text colorful, bold or italic.
# 9. Add a link to a youtube video of the destination.
# 10. Add relevant annotations to explain any function or module you have used

# %%
# Pre-built python function that will ask you for your name

print("What is your name?")
x = input()
# Out:
# What is your name?
# Lucas

# %% [markdown]
# ### Selfie Time!
#
# ![Angola.jpeg](attachment:Angola.jpeg)

# %%
# Pre-built python function that will ask you for your holiday preferences

print("Do you prefer going to the sea or the mountain?")
x = input()
# Out:
# Do you prefer going to the sea or the mountain?
# sea

# %%
# Pre-built python function that will ask you for your holiday preferences

print("When on holidays, are you more into adventures or local tourism?")
x = input()
# Out:
# When on holidays, are you more into adventures or local tourism?
# Adentures

# %%
# Pre-built python function that will ask you for your holiday preferences

print("Would you rather go backpacking or to a hotel with everything paid for?")
x = input()
# Out:
# Would you rather go backpacking or to a hotel with everything paid for?
# backpacking

# %% [markdown]
# ### Beautiful Thailand!
#
# ![thailand.png](attachment:thailand.png)

# %% [markdown]
# ### My ideal holiday activities in bullet points:
# - A **<font color = red>warm</font>** country over a __<font color = blue>cold</font>__ one
# - Where i can go _Bungee Jumping_
# - and _Scuba Diving_
# - Let´s go to **Thailand!**

# %% [markdown]
# ### Video
#
# [Click here to see an amazing video of Thailand!](https://www.youtube.com/watch?v=SYCWtytwWI0)
